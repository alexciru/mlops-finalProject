# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import pytorch_lightning as pl
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, random_split
import wandb
from pytorch_lightning.loggers import WandbLogger
from mlops_finalproject.models import model
from pytorch_lightning import Callback, Trainer
from torchvision import transforms
import pandas as pd
from PIL import Image
from torchvision import transforms, datasets
from tqdm.notebook import tqdm

# %%
images = torch.load("../data/processed/32/images.pt")
labels = torch.load("../data/processed/32/labels.pt")

train_dataset = TensorDataset(images, labels)  # create your datset
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False, num_workers=8)

# %%
# for _, l in train_loader:
#     print(l)

# %%
import torchvision.models as models
import torch.nn as nn
def build_model(pretrained=True, fine_tune=False, num_classes=10):
    if pretrained:
        print('[INFO]: Loading pre-trained weights')
    else:
        print('[INFO]: Not loading pre-trained weights')
    model = models.mobilenet_v3_large(pretrained=pretrained)
    if fine_tune:
        print('[INFO]: Fine-tuning all layers...')
        for params in model.parameters():
            params.requires_grad = True
    elif not fine_tune:
        print('[INFO]: Freezing hidden layers...')
        for params in model.parameters():
            params.requires_grad = False
    # Change the final classification head.
    model.classifier[3] = nn.Linear(in_features=1280, out_features=num_classes)
    return model

# %%
# Training function.
def train(
    model, trainloader, optimizer, 
    criterion, scheduler=None, epoch=None
):
    model.train()
    print('Training')
    train_running_loss = 0.0
    train_running_correct = 0
    counter = 0
    iters = len(trainloader)
    for i, data in enumerate(trainloader):
        counter += 1
        image, labels = data
        image = image.to("cpu")
        labels = labels.to("cpu")
        optimizer.zero_grad()
        # Forward pass.
        outputs = model(image)
        # Calculate the loss.
        loss = criterion(outputs, labels)
        train_running_loss += loss.item()
        # Calculate the accuracy.
        _, preds = torch.max(outputs.data, 1)
        train_running_correct += (preds == labels).sum().item()
        # Backpropagation.
        loss.backward()
        # Update the weights.
        optimizer.step()
        if scheduler is not None:
            scheduler.step(epoch + i / iters)
    
    # Loss and accuracy for the complete epoch.
    epoch_loss = train_running_loss / counter
    epoch_acc = 100. * (train_running_correct / len(trainloader.dataset))
    return epoch_loss, epoch_acc

# %%
# Validation function.
def validate(model, testloader, criterion, class_names):
    model.eval()
    print('Validation')
    valid_running_loss = 0.0
    valid_running_correct = 0
    counter = 0
    # We need two lists to keep track of class-wise accuracy.
    class_correct = list(0. for i in range(len(class_names)))
    class_total = list(0. for i in range(len(class_names)))
    with torch.no_grad():
        for i, data in enumerate(testloader):
            counter += 1
            
            image, labels = data
            image = image.to("cpu")
            labels = labels.to("cpu")
            # Forward pass.
            outputs = model(image)
            # Calculate the loss.
            loss = criterion(outputs, labels)
            valid_running_loss += loss.item()
            # Calculate the accuracy.
            _, preds = torch.max(outputs.data, 1)
            valid_running_correct += (preds == labels).sum().item()
            # Calculate the accuracy for each class.
            correct  = (preds == labels).squeeze()
            for i in range(len(preds)):
                label = labels[i]
                class_correct[label] += correct[i].item()
                class_total[label] += 1
        
    # Loss and accuracy for the complete epoch.
    epoch_loss = valid_running_loss / counter
    epoch_acc = 100. * (valid_running_correct / len(testloader.dataset))
    # Print the accuracy for each class after every epoch.
    print('\n')
    for i in range(len(class_names)):
        print(f"Accuracy of class {class_names[i]}: {100*class_correct[i]/class_total[i]}")
    print('\n')
    return epoch_loss, epoch_acc

# %%
from torch import nn, optim
import time

pretrained=True
fine_tune=True

epochs = 4

# Load the model.
model = build_model(
    pretrained=pretrained,
    fine_tune=fine_tune, 
    num_classes=43
).to('cpu')

# Total parameters and trainable parameters.
total_params = sum(p.numel() for p in model.parameters())
print(f"{total_params:,} total parameters.")
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f"{total_trainable_params:,} training parameters.")
# Optimizer.
optimizer = optim.Adam(model.parameters(), lr=0.001)
# Loss function.
criterion = nn.CrossEntropyLoss()
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer, 
    T_0=10, 
    T_mult=1,
    verbose=True
)
# Lists to keep track of losses and accuracies.
train_loss, valid_loss = [], []
train_acc, valid_acc = [], []
# Start the training.
for epoch in range(epochs):
    print(f"[INFO]: Epoch {epoch+1} of {epochs}")
    train_epoch_loss, train_epoch_acc = train(
        model, train_loader, 
        optimizer, criterion,
        scheduler=scheduler, epoch=epoch
    )
    valid_epoch_loss, valid_epoch_acc = validate(model, train_loader,  
                                                criterion, [i for i in range(43)])
    train_loss.append(train_epoch_loss)
    valid_loss.append(valid_epoch_loss)
    train_acc.append(train_epoch_acc)
    valid_acc.append(valid_epoch_acc)
    print(f"Training loss: {train_epoch_loss:.3f}, training acc: {train_epoch_acc:.3f}")
    print(f"Validation loss: {valid_epoch_loss:.3f}, validation acc: {valid_epoch_acc:.3f}")
    print('-'*50)
    time.sleep(5)
    
# # Save the trained model weights.
# save_model(epochs, model, optimizer, criterion)
# # Save the loss and accuracy plots.
# save_plots(train_acc, valid_acc, train_loss, valid_loss)
print('TRAINING COMPLETE')
# Out:
# [INFO]: Loading pre-trained weights
# [INFO]: Fine-tuning all layers...
# 4,257,115 total parameters.
# 4,257,115 training parameters.
# Epoch 00000: adjusting learning rate of group 0 to 1.0000e-03.
# [INFO]: Epoch 1 of 4
# Training
# /home/javi/.virtualenvs/mlops-project/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/javi/.virtualenvs/mlops-project/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Large_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Large_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 0.00: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.00: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.00: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.00: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.01: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.01: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.01: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.01: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.01: adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 0.01: adjusting learning rate of group 0 to 9.9999e-04.
# Epoch 0.02: adjusting learning rate of group 0 to 9.9999e-04.
# Epoch 0.02: adjusting learning rate of group 0 to 9.9999e-04.
# Epoch 0.02: adjusting learning rate of group 0 to 9.9999e-04.
# Epoch 0.02: adjusting learning rate of group 0 to 9.9999e-04.
# Epoch 0.02: adjusting learning rate of group 0 to 9.9999e-04.
# Epoch 0.02: adjusting learning rate of group 0 to 9.9999e-04.
# Epoch 0.03: adjusting learning rate of group 0 to 9.9998e-04.
# Epoch 0.03: adjusting learning rate of group 0 to 9.9998e-04.
# Epoch 0.03: adjusting learning rate of group 0 to 9.9998e-04.
# Epoch 0.03: adjusting learning rate of group 0 to 9.9998e-04.
# Epoch 0.03: adjusting learning rate of group 0 to 9.9997e-04.
# Epoch 0.03: adjusting learning rate of group 0 to 9.9997e-04.
# Epoch 0.04: adjusting learning rate of group 0 to 9.9997e-04.
# Epoch 0.04: adjusting learning rate of group 0 to 9.9997e-04.
# Epoch 0.04: adjusting learning rate of group 0 to 9.9996e-04.
# Epoch 0.04: adjusting learning rate of group 0 to 9.9996e-04.
# Epoch 0.04: adjusting learning rate of group 0 to 9.9996e-04.
# Epoch 0.04: adjusting learning rate of group 0 to 9.9995e-04.
# Epoch 0.05: adjusting learning rate of group 0 to 9.9995e-04.
# Epoch 0.05: adjusting learning rate of group 0 to 9.9994e-04.
# Epoch 0.05: adjusting learning rate of group 0 to 9.9994e-04.
# Epoch 0.05: adjusting learning rate of group 0 to 9.9994e-04.
# Epoch 0.05: adjusting learning rate of group 0 to 9.9993e-04.
# Epoch 0.05: adjusting learning rate of group 0 to 9.9993e-04.
# Epoch 0.06: adjusting learning rate of group 0 to 9.9992e-04.
# Epoch 0.06: adjusting learning rate of group 0 to 9.9992e-04.
# Epoch 0.06: adjusting learning rate of group 0 to 9.9991e-04.
# Epoch 0.06: adjusting learning rate of group 0 to 9.9991e-04.
# Epoch 0.06: adjusting learning rate of group 0 to 9.9991e-04.
# Epoch 0.06: adjusting learning rate of group 0 to 9.9990e-04.
# Epoch 0.07: adjusting learning rate of group 0 to 9.9989e-04.
# Epoch 0.07: adjusting learning rate of group 0 to 9.9989e-04.
# Epoch 0.07: adjusting learning rate of group 0 to 9.9988e-04.
# Epoch 0.07: adjusting learning rate of group 0 to 9.9988e-04.
# Epoch 0.07: adjusting learning rate of group 0 to 9.9987e-04.
# Epoch 0.07: adjusting learning rate of group 0 to 9.9987e-04.
# Epoch 0.08: adjusting learning rate of group 0 to 9.9986e-04.
# Epoch 0.08: adjusting learning rate of group 0 to 9.9985e-04.
# Epoch 0.08: adjusting learning rate of group 0 to 9.9985e-04.
# Epoch 0.08: adjusting learning rate of group 0 to 9.9984e-04.
# Epoch 0.08: adjusting learning rate of group 0 to 9.9984e-04.
# Epoch 0.08: adjusting learning rate of group 0 to 9.9983e-04.
# Epoch 0.08: adjusting learning rate of group 0 to 9.9982e-04.
# Epoch 0.09: adjusting learning rate of group 0 to 9.9982e-04.
# Epoch 0.09: adjusting learning rate of group 0 to 9.9981e-04.
# Epoch 0.09: adjusting learning rate of group 0 to 9.9980e-04.
# Epoch 0.09: adjusting learning rate of group 0 to 9.9979e-04.
# Epoch 0.09: adjusting learning rate of group 0 to 9.9979e-04.
# Epoch 0.09: adjusting learning rate of group 0 to 9.9978e-04.
# Epoch 0.10: adjusting learning rate of group 0 to 9.9977e-04.
# Epoch 0.10: adjusting learning rate of group 0 to 9.9976e-04.
# Epoch 0.10: adjusting learning rate of group 0 to 9.9976e-04.
# Epoch 0.10: adjusting learning rate of group 0 to 9.9975e-04.
# Epoch 0.10: adjusting learning rate of group 0 to 9.9974e-04.
# Epoch 0.10: adjusting learning rate of group 0 to 9.9973e-04.
# Epoch 0.11: adjusting learning rate of group 0 to 9.9972e-04.
# Epoch 0.11: adjusting learning rate of group 0 to 9.9971e-04.
# Epoch 0.11: adjusting learning rate of group 0 to 9.9971e-04.
# Epoch 0.11: adjusting learning rate of group 0 to 9.9970e-04.
# Epoch 0.11: adjusting learning rate of group 0 to 9.9969e-04.
# Epoch 0.11: adjusting learning rate of group 0 to 9.9968e-04.
# Epoch 0.12: adjusting learning rate of group 0 to 9.9967e-04.
# Epoch 0.12: adjusting learning rate of group 0 to 9.9966e-04.
# Epoch 0.12: adjusting learning rate of group 0 to 9.9965e-04.
# Epoch 0.12: adjusting learning rate of group 0 to 9.9964e-04.
# Epoch 0.12: adjusting learning rate of group 0 to 9.9963e-04.
# Epoch 0.12: adjusting learning rate of group 0 to 9.9962e-04.
# Epoch 0.13: adjusting learning rate of group 0 to 9.9961e-04.
# Epoch 0.13: adjusting learning rate of group 0 to 9.9960e-04.
# Epoch 0.13: adjusting learning rate of group 0 to 9.9959e-04.
# Epoch 0.13: adjusting learning rate of group 0 to 9.9958e-04.
# Epoch 0.13: adjusting learning rate of group 0 to 9.9957e-04.
# Epoch 0.13: adjusting learning rate of group 0 to 9.9956e-04.
# Epoch 0.14: adjusting learning rate of group 0 to 9.9955e-04.
# Epoch 0.14: adjusting learning rate of group 0 to 9.9954e-04.
# Epoch 0.14: adjusting learning rate of group 0 to 9.9953e-04.
# Epoch 0.14: adjusting learning rate of group 0 to 9.9951e-04.
# Epoch 0.14: adjusting learning rate of group 0 to 9.9950e-04.
# Epoch 0.14: adjusting learning rate of group 0 to 9.9949e-04.
# Epoch 0.15: adjusting learning rate of group 0 to 9.9948e-04.
# Epoch 0.15: adjusting learning rate of group 0 to 9.9947e-04.
# Epoch 0.15: adjusting learning rate of group 0 to 9.9946e-04.
# Epoch 0.15: adjusting learning rate of group 0 to 9.9944e-04.
# Epoch 0.15: adjusting learning rate of group 0 to 9.9943e-04.
# Epoch 0.15: adjusting learning rate of group 0 to 9.9942e-04.
# Epoch 0.15: adjusting learning rate of group 0 to 9.9941e-04.
# Epoch 0.16: adjusting learning rate of group 0 to 9.9939e-04.
# Epoch 0.16: adjusting learning rate of group 0 to 9.9938e-04.
# Epoch 0.16: adjusting learning rate of group 0 to 9.9937e-04.
# Epoch 0.16: adjusting learning rate of group 0 to 9.9936e-04.
# Epoch 0.16: adjusting learning rate of group 0 to 9.9934e-04.
# Epoch 0.16: adjusting learning rate of group 0 to 9.9933e-04.
# Epoch 0.17: adjusting learning rate of group 0 to 9.9932e-04.
# Epoch 0.17: adjusting learning rate of group 0 to 9.9930e-04.
# Epoch 0.17: adjusting learning rate of group 0 to 9.9929e-04.
# Epoch 0.17: adjusting learning rate of group 0 to 9.9928e-04.
# Epoch 0.17: adjusting learning rate of group 0 to 9.9926e-04.
# Epoch 0.17: adjusting learning rate of group 0 to 9.9925e-04.
# Epoch 0.18: adjusting learning rate of group 0 to 9.9923e-04.
# Epoch 0.18: adjusting learning rate of group 0 to 9.9922e-04.
# Epoch 0.18: adjusting learning rate of group 0 to 9.9921e-04.
# Epoch 0.18: adjusting learning rate of group 0 to 9.9919e-04.
# Epoch 0.18: adjusting learning rate of group 0 to 9.9918e-04.
# Epoch 0.18: adjusting learning rate of group 0 to 9.9916e-04.
# Epoch 0.19: adjusting learning rate of group 0 to 9.9915e-04.
# Epoch 0.19: adjusting learning rate of group 0 to 9.9913e-04.
# Epoch 0.19: adjusting learning rate of group 0 to 9.9912e-04.
# Epoch 0.19: adjusting learning rate of group 0 to 9.9910e-04.
# Epoch 0.19: adjusting learning rate of group 0 to 9.9909e-04.
# Epoch 0.19: adjusting learning rate of group 0 to 9.9907e-04.
# Epoch 0.20: adjusting learning rate of group 0 to 9.9905e-04.
# Epoch 0.20: adjusting learning rate of group 0 to 9.9904e-04.
# Epoch 0.20: adjusting learning rate of group 0 to 9.9902e-04.
# Epoch 0.20: adjusting learning rate of group 0 to 9.9901e-04.
# Epoch 0.20: adjusting learning rate of group 0 to 9.9899e-04.
# Epoch 0.20: adjusting learning rate of group 0 to 9.9897e-04.
# Epoch 0.21: adjusting learning rate of group 0 to 9.9896e-04.
# Epoch 0.21: adjusting learning rate of group 0 to 9.9894e-04.
# Epoch 0.21: adjusting learning rate of group 0 to 9.9892e-04.
# Epoch 0.21: adjusting learning rate of group 0 to 9.9891e-04.
# Epoch 0.21: adjusting learning rate of group 0 to 9.9889e-04.
# Epoch 0.21: adjusting learning rate of group 0 to 9.9887e-04.
# Epoch 0.22: adjusting learning rate of group 0 to 9.9886e-04.
# Epoch 0.22: adjusting learning rate of group 0 to 9.9884e-04.
# Epoch 0.22: adjusting learning rate of group 0 to 9.9882e-04.
# Epoch 0.22: adjusting learning rate of group 0 to 9.9880e-04.
# Epoch 0.22: adjusting learning rate of group 0 to 9.9879e-04.
# Epoch 0.22: adjusting learning rate of group 0 to 9.9877e-04.
# Epoch 0.23: adjusting learning rate of group 0 to 9.9875e-04.
# Epoch 0.23: adjusting learning rate of group 0 to 9.9873e-04.
# Epoch 0.23: adjusting learning rate of group 0 to 9.9871e-04.
# Epoch 0.23: adjusting learning rate of group 0 to 9.9870e-04.
# Epoch 0.23: adjusting learning rate of group 0 to 9.9868e-04.
# Epoch 0.23: adjusting learning rate of group 0 to 9.9866e-04.
# Epoch 0.23: adjusting learning rate of group 0 to 9.9864e-04.
# Epoch 0.24: adjusting learning rate of group 0 to 9.9862e-04.
# Epoch 0.24: adjusting learning rate of group 0 to 9.9860e-04.
# Epoch 0.24: adjusting learning rate of group 0 to 9.9858e-04.
# Epoch 0.24: adjusting learning rate of group 0 to 9.9856e-04.
# Epoch 0.24: adjusting learning rate of group 0 to 9.9854e-04.
# Epoch 0.24: adjusting learning rate of group 0 to 9.9852e-04.
# Epoch 0.25: adjusting learning rate of group 0 to 9.9850e-04.
# Epoch 0.25: adjusting learning rate of group 0 to 9.9848e-04.
# Epoch 0.25: adjusting learning rate of group 0 to 9.9846e-04.
# Epoch 0.25: adjusting learning rate of group 0 to 9.9844e-04.
# Epoch 0.25: adjusting learning rate of group 0 to 9.9842e-04.
# Epoch 0.25: adjusting learning rate of group 0 to 9.9840e-04.
# Epoch 0.26: adjusting learning rate of group 0 to 9.9838e-04.
# Epoch 0.26: adjusting learning rate of group 0 to 9.9836e-04.
# Epoch 0.26: adjusting learning rate of group 0 to 9.9834e-04.
# Epoch 0.26: adjusting learning rate of group 0 to 9.9832e-04.
# Epoch 0.26: adjusting learning rate of group 0 to 9.9830e-04.
# Epoch 0.26: adjusting learning rate of group 0 to 9.9828e-04.
# Epoch 0.27: adjusting learning rate of group 0 to 9.9826e-04.
# Epoch 0.27: adjusting learning rate of group 0 to 9.9823e-04.
# Epoch 0.27: adjusting learning rate of group 0 to 9.9821e-04.
# Epoch 0.27: adjusting learning rate of group 0 to 9.9819e-04.
# Epoch 0.27: adjusting learning rate of group 0 to 9.9817e-04.
# Epoch 0.27: adjusting learning rate of group 0 to 9.9815e-04.
# Epoch 0.28: adjusting learning rate of group 0 to 9.9813e-04.
# Epoch 0.28: adjusting learning rate of group 0 to 9.9810e-04.
# Epoch 0.28: adjusting learning rate of group 0 to 9.9808e-04.
# Epoch 0.28: adjusting learning rate of group 0 to 9.9806e-04.
# Epoch 0.28: adjusting learning rate of group 0 to 9.9804e-04.
# Epoch 0.28: adjusting learning rate of group 0 to 9.9801e-04.
# Epoch 0.29: adjusting learning rate of group 0 to 9.9799e-04.
# Epoch 0.29: adjusting learning rate of group 0 to 9.9797e-04.
# Epoch 0.29: adjusting learning rate of group 0 to 9.9794e-04.
# Epoch 0.29: adjusting learning rate of group 0 to 9.9792e-04.
# Epoch 0.29: adjusting learning rate of group 0 to 9.9790e-04.
# Epoch 0.29: adjusting learning rate of group 0 to 9.9787e-04.
# Epoch 0.30: adjusting learning rate of group 0 to 9.9785e-04.
# Epoch 0.30: adjusting learning rate of group 0 to 9.9783e-04.
# Epoch 0.30: adjusting learning rate of group 0 to 9.9780e-04.
# Epoch 0.30: adjusting learning rate of group 0 to 9.9778e-04.
# Epoch 0.30: adjusting learning rate of group 0 to 9.9775e-04.
# Epoch 0.30: adjusting learning rate of group 0 to 9.9773e-04.
# Epoch 0.31: adjusting learning rate of group 0 to 9.9771e-04.
# Epoch 0.31: adjusting learning rate of group 0 to 9.9768e-04.
# Epoch 0.31: adjusting learning rate of group 0 to 9.9766e-04.
# Epoch 0.31: adjusting learning rate of group 0 to 9.9763e-04.
# Epoch 0.31: adjusting learning rate of group 0 to 9.9761e-04.
# Epoch 0.31: adjusting learning rate of group 0 to 9.9758e-04.
# Epoch 0.31: adjusting learning rate of group 0 to 9.9756e-04.
# Epoch 0.32: adjusting learning rate of group 0 to 9.9753e-04.
# Epoch 0.32: adjusting learning rate of group 0 to 9.9751e-04.
# Epoch 0.32: adjusting learning rate of group 0 to 9.9748e-04.
# Epoch 0.32: adjusting learning rate of group 0 to 9.9745e-04.
# Epoch 0.32: adjusting learning rate of group 0 to 9.9743e-04.
# Epoch 0.32: adjusting learning rate of group 0 to 9.9740e-04.
# Epoch 0.33: adjusting learning rate of group 0 to 9.9738e-04.
# Epoch 0.33: adjusting learning rate of group 0 to 9.9735e-04.
# Epoch 0.33: adjusting learning rate of group 0 to 9.9732e-04.
# Epoch 0.33: adjusting learning rate of group 0 to 9.9730e-04.
# Epoch 0.33: adjusting learning rate of group 0 to 9.9727e-04.
# Epoch 0.33: adjusting learning rate of group 0 to 9.9724e-04.
# Epoch 0.34: adjusting learning rate of group 0 to 9.9722e-04.
# Epoch 0.34: adjusting learning rate of group 0 to 9.9719e-04.
# Epoch 0.34: adjusting learning rate of group 0 to 9.9716e-04.
# Epoch 0.34: adjusting learning rate of group 0 to 9.9713e-04.
# Epoch 0.34: adjusting learning rate of group 0 to 9.9711e-04.
# Epoch 0.34: adjusting learning rate of group 0 to 9.9708e-04.
# Epoch 0.35: adjusting learning rate of group 0 to 9.9705e-04.
# Epoch 0.35: adjusting learning rate of group 0 to 9.9702e-04.
# Epoch 0.35: adjusting learning rate of group 0 to 9.9700e-04.
# Epoch 0.35: adjusting learning rate of group 0 to 9.9697e-04.
# Epoch 0.35: adjusting learning rate of group 0 to 9.9694e-04.
# Epoch 0.35: adjusting learning rate of group 0 to 9.9691e-04.
# Epoch 0.36: adjusting learning rate of group 0 to 9.9688e-04.
# Epoch 0.36: adjusting learning rate of group 0 to 9.9685e-04.
# Epoch 0.36: adjusting learning rate of group 0 to 9.9683e-04.
# Epoch 0.36: adjusting learning rate of group 0 to 9.9680e-04.
# Epoch 0.36: adjusting learning rate of group 0 to 9.9677e-04.
# Epoch 0.36: adjusting learning rate of group 0 to 9.9674e-04.
# Epoch 0.37: adjusting learning rate of group 0 to 9.9671e-04.
# Epoch 0.37: adjusting learning rate of group 0 to 9.9668e-04.
# Epoch 0.37: adjusting learning rate of group 0 to 9.9665e-04.
# Epoch 0.37: adjusting learning rate of group 0 to 9.9662e-04.
# Epoch 0.37: adjusting learning rate of group 0 to 9.9659e-04.
# Epoch 0.37: adjusting learning rate of group 0 to 9.9656e-04.
# Epoch 0.38: adjusting learning rate of group 0 to 9.9653e-04.
# Epoch 0.38: adjusting learning rate of group 0 to 9.9650e-04.
# Epoch 0.38: adjusting learning rate of group 0 to 9.9647e-04.
# Epoch 0.38: adjusting learning rate of group 0 to 9.9644e-04.
# Epoch 0.38: adjusting learning rate of group 0 to 9.9641e-04.
# Epoch 0.38: adjusting learning rate of group 0 to 9.9638e-04.
# Epoch 0.38: adjusting learning rate of group 0 to 9.9635e-04.
# Epoch 0.39: adjusting learning rate of group 0 to 9.9632e-04.
# Epoch 0.39: adjusting learning rate of group 0 to 9.9629e-04.
# Epoch 0.39: adjusting learning rate of group 0 to 9.9625e-04.
# Epoch 0.39: adjusting learning rate of group 0 to 9.9622e-04.
# Epoch 0.39: adjusting learning rate of group 0 to 9.9619e-04.
# Epoch 0.39: adjusting learning rate of group 0 to 9.9616e-04.
# Epoch 0.40: adjusting learning rate of group 0 to 9.9613e-04.
# Epoch 0.40: adjusting learning rate of group 0 to 9.9610e-04.
# Epoch 0.40: adjusting learning rate of group 0 to 9.9606e-04.
# Epoch 0.40: adjusting learning rate of group 0 to 9.9603e-04.
# Epoch 0.40: adjusting learning rate of group 0 to 9.9600e-04.
# Epoch 0.40: adjusting learning rate of group 0 to 9.9597e-04.
# Epoch 0.41: adjusting learning rate of group 0 to 9.9593e-04.
# Epoch 0.41: adjusting learning rate of group 0 to 9.9590e-04.
# Epoch 0.41: adjusting learning rate of group 0 to 9.9587e-04.
# Epoch 0.41: adjusting learning rate of group 0 to 9.9584e-04.
# Epoch 0.41: adjusting learning rate of group 0 to 9.9580e-04.
# Epoch 0.41: adjusting learning rate of group 0 to 9.9577e-04.
# Epoch 0.42: adjusting learning rate of group 0 to 9.9574e-04.
# Epoch 0.42: adjusting learning rate of group 0 to 9.9570e-04.
# Epoch 0.42: adjusting learning rate of group 0 to 9.9567e-04.
# Epoch 0.42: adjusting learning rate of group 0 to 9.9564e-04.
# Epoch 0.42: adjusting learning rate of group 0 to 9.9560e-04.
# Epoch 0.42: adjusting learning rate of group 0 to 9.9557e-04.
# Epoch 0.43: adjusting learning rate of group 0 to 9.9553e-04.
# Epoch 0.43: adjusting learning rate of group 0 to 9.9550e-04.
# Epoch 0.43: adjusting learning rate of group 0 to 9.9547e-04.
# Epoch 0.43: adjusting learning rate of group 0 to 9.9543e-04.
# Epoch 0.43: adjusting learning rate of group 0 to 9.9540e-04.
# Epoch 0.43: adjusting learning rate of group 0 to 9.9536e-04.
# Epoch 0.44: adjusting learning rate of group 0 to 9.9533e-04.
# Epoch 0.44: adjusting learning rate of group 0 to 9.9529e-04.
# Epoch 0.44: adjusting learning rate of group 0 to 9.9526e-04.
# Epoch 0.44: adjusting learning rate of group 0 to 9.9522e-04.
# Epoch 0.44: adjusting learning rate of group 0 to 9.9519e-04.
# Epoch 0.44: adjusting learning rate of group 0 to 9.9515e-04.
# Epoch 0.45: adjusting learning rate of group 0 to 9.9511e-04.
# Epoch 0.45: adjusting learning rate of group 0 to 9.9508e-04.
# Epoch 0.45: adjusting learning rate of group 0 to 9.9504e-04.
# Epoch 0.45: adjusting learning rate of group 0 to 9.9501e-04.
# Epoch 0.45: adjusting learning rate of group 0 to 9.9497e-04.
# Epoch 0.45: adjusting learning rate of group 0 to 9.9493e-04.
# Epoch 0.46: adjusting learning rate of group 0 to 9.9490e-04.
# Epoch 0.46: adjusting learning rate of group 0 to 9.9486e-04.
# Epoch 0.46: adjusting learning rate of group 0 to 9.9482e-04.
# Epoch 0.46: adjusting learning rate of group 0 to 9.9479e-04.
# Epoch 0.46: adjusting learning rate of group 0 to 9.9475e-04.
# Epoch 0.46: adjusting learning rate of group 0 to 9.9471e-04.
# Epoch 0.46: adjusting learning rate of group 0 to 9.9468e-04.
# Epoch 0.47: adjusting learning rate of group 0 to 9.9464e-04.
# Epoch 0.47: adjusting learning rate of group 0 to 9.9460e-04.
# Epoch 0.47: adjusting learning rate of group 0 to 9.9456e-04.
# Epoch 0.47: adjusting learning rate of group 0 to 9.9453e-04.
# Epoch 0.47: adjusting learning rate of group 0 to 9.9449e-04.
# Epoch 0.47: adjusting learning rate of group 0 to 9.9445e-04.
# Epoch 0.48: adjusting learning rate of group 0 to 9.9441e-04.
# Epoch 0.48: adjusting learning rate of group 0 to 9.9437e-04.
# Epoch 0.48: adjusting learning rate of group 0 to 9.9434e-04.
# Epoch 0.48: adjusting learning rate of group 0 to 9.9430e-04.
# Epoch 0.48: adjusting learning rate of group 0 to 9.9426e-04.
# Epoch 0.48: adjusting learning rate of group 0 to 9.9422e-04.
# Epoch 0.49: adjusting learning rate of group 0 to 9.9418e-04.
# Epoch 0.49: adjusting learning rate of group 0 to 9.9414e-04.
# Epoch 0.49: adjusting learning rate of group 0 to 9.9410e-04.
# Epoch 0.49: adjusting learning rate of group 0 to 9.9406e-04.
# Epoch 0.49: adjusting learning rate of group 0 to 9.9402e-04.
# Epoch 0.49: adjusting learning rate of group 0 to 9.9398e-04.
# Epoch 0.50: adjusting learning rate of group 0 to 9.9394e-04.
# Epoch 0.50: adjusting learning rate of group 0 to 9.9390e-04.
# Epoch 0.50: adjusting learning rate of group 0 to 9.9386e-04.
# Epoch 0.50: adjusting learning rate of group 0 to 9.9382e-04.
# Epoch 0.50: adjusting learning rate of group 0 to 9.9378e-04.
# Epoch 0.50: adjusting learning rate of group 0 to 9.9374e-04.
# Epoch 0.51: adjusting learning rate of group 0 to 9.9370e-04.
# Epoch 0.51: adjusting learning rate of group 0 to 9.9366e-04.
# Epoch 0.51: adjusting learning rate of group 0 to 9.9362e-04.
# Epoch 0.51: adjusting learning rate of group 0 to 9.9358e-04.
# Epoch 0.51: adjusting learning rate of group 0 to 9.9354e-04.
# Epoch 0.51: adjusting learning rate of group 0 to 9.9350e-04.
# Epoch 0.52: adjusting learning rate of group 0 to 9.9346e-04.
# Epoch 0.52: adjusting learning rate of group 0 to 9.9342e-04.
# Epoch 0.52: adjusting learning rate of group 0 to 9.9337e-04.
# Epoch 0.52: adjusting learning rate of group 0 to 9.9333e-04.
# Epoch 0.52: adjusting learning rate of group 0 to 9.9329e-04.
# Epoch 0.52: adjusting learning rate of group 0 to 9.9325e-04.
# Epoch 0.53: adjusting learning rate of group 0 to 9.9321e-04.
# Epoch 0.53: adjusting learning rate of group 0 to 9.9317e-04.
# Epoch 0.53: adjusting learning rate of group 0 to 9.9312e-04.
# Epoch 0.53: adjusting learning rate of group 0 to 9.9308e-04.
# Epoch 0.53: adjusting learning rate of group 0 to 9.9304e-04.
# Epoch 0.53: adjusting learning rate of group 0 to 9.9300e-04.
# Epoch 0.54: adjusting learning rate of group 0 to 9.9295e-04.
# Epoch 0.54: adjusting learning rate of group 0 to 9.9291e-04.
# Epoch 0.54: adjusting learning rate of group 0 to 9.9287e-04.
# Epoch 0.54: adjusting learning rate of group 0 to 9.9282e-04.
# Epoch 0.54: adjusting learning rate of group 0 to 9.9278e-04.
# Epoch 0.54: adjusting learning rate of group 0 to 9.9274e-04.
# Epoch 0.54: adjusting learning rate of group 0 to 9.9269e-04.
# Epoch 0.55: adjusting learning rate of group 0 to 9.9265e-04.
# Epoch 0.55: adjusting learning rate of group 0 to 9.9261e-04.
# Epoch 0.55: adjusting learning rate of group 0 to 9.9256e-04.
# Epoch 0.55: adjusting learning rate of group 0 to 9.9252e-04.
# Epoch 0.55: adjusting learning rate of group 0 to 9.9247e-04.
# Epoch 0.55: adjusting learning rate of group 0 to 9.9243e-04.
# Epoch 0.56: adjusting learning rate of group 0 to 9.9238e-04.
# Epoch 0.56: adjusting learning rate of group 0 to 9.9234e-04.
# Epoch 0.56: adjusting learning rate of group 0 to 9.9229e-04.
# Epoch 0.56: adjusting learning rate of group 0 to 9.9225e-04.
# Epoch 0.56: adjusting learning rate of group 0 to 9.9220e-04.
# Epoch 0.56: adjusting learning rate of group 0 to 9.9216e-04.
# Epoch 0.57: adjusting learning rate of group 0 to 9.9211e-04.
# Epoch 0.57: adjusting learning rate of group 0 to 9.9207e-04.
# Epoch 0.57: adjusting learning rate of group 0 to 9.9202e-04.
# Epoch 0.57: adjusting learning rate of group 0 to 9.9198e-04.
# Epoch 0.57: adjusting learning rate of group 0 to 9.9193e-04.
# Epoch 0.57: adjusting learning rate of group 0 to 9.9189e-04.
# Epoch 0.58: adjusting learning rate of group 0 to 9.9184e-04.
# Epoch 0.58: adjusting learning rate of group 0 to 9.9179e-04.
# Epoch 0.58: adjusting learning rate of group 0 to 9.9175e-04.
# Epoch 0.58: adjusting learning rate of group 0 to 9.9170e-04.
# Epoch 0.58: adjusting learning rate of group 0 to 9.9165e-04.
# Epoch 0.58: adjusting learning rate of group 0 to 9.9161e-04.
# Epoch 0.59: adjusting learning rate of group 0 to 9.9156e-04.
# Epoch 0.59: adjusting learning rate of group 0 to 9.9151e-04.
# Epoch 0.59: adjusting learning rate of group 0 to 9.9147e-04.
# Epoch 0.59: adjusting learning rate of group 0 to 9.9142e-04.
# Epoch 0.59: adjusting learning rate of group 0 to 9.9137e-04.
# Epoch 0.59: adjusting learning rate of group 0 to 9.9133e-04.
# Epoch 0.60: adjusting learning rate of group 0 to 9.9128e-04.
# Epoch 0.60: adjusting learning rate of group 0 to 9.9123e-04.
# Epoch 0.60: adjusting learning rate of group 0 to 9.9118e-04.
# Epoch 0.60: adjusting learning rate of group 0 to 9.9113e-04.
# Epoch 0.60: adjusting learning rate of group 0 to 9.9109e-04.
# Epoch 0.60: adjusting learning rate of group 0 to 9.9104e-04.
# Epoch 0.61: adjusting learning rate of group 0 to 9.9099e-04.
# Epoch 0.61: adjusting learning rate of group 0 to 9.9094e-04.
# Epoch 0.61: adjusting learning rate of group 0 to 9.9089e-04.
# Epoch 0.61: adjusting learning rate of group 0 to 9.9084e-04.
# Epoch 0.61: adjusting learning rate of group 0 to 9.9079e-04.
# Epoch 0.61: adjusting learning rate of group 0 to 9.9075e-04.
# Epoch 0.62: adjusting learning rate of group 0 to 9.9070e-04.
# Epoch 0.62: adjusting learning rate of group 0 to 9.9065e-04.
# Epoch 0.62: adjusting learning rate of group 0 to 9.9060e-04.
# Epoch 0.62: adjusting learning rate of group 0 to 9.9055e-04.
# Epoch 0.62: adjusting learning rate of group 0 to 9.9050e-04.
# Epoch 0.62: adjusting learning rate of group 0 to 9.9045e-04.
# Epoch 0.62: adjusting learning rate of group 0 to 9.9040e-04.
# Epoch 0.63: adjusting learning rate of group 0 to 9.9035e-04.
# Epoch 0.63: adjusting learning rate of group 0 to 9.9030e-04.
# Epoch 0.63: adjusting learning rate of group 0 to 9.9025e-04.
# Epoch 0.63: adjusting learning rate of group 0 to 9.9020e-04.
# Epoch 0.63: adjusting learning rate of group 0 to 9.9015e-04.
# Epoch 0.63: adjusting learning rate of group 0 to 9.9010e-04.
# Epoch 0.64: adjusting learning rate of group 0 to 9.9005e-04.
# Epoch 0.64: adjusting learning rate of group 0 to 9.8999e-04.
# Epoch 0.64: adjusting learning rate of group 0 to 9.8994e-04.
# Epoch 0.64: adjusting learning rate of group 0 to 9.8989e-04.
# Epoch 0.64: adjusting learning rate of group 0 to 9.8984e-04.
# Epoch 0.64: adjusting learning rate of group 0 to 9.8979e-04.
# Epoch 0.65: adjusting learning rate of group 0 to 9.8974e-04.
# Epoch 0.65: adjusting learning rate of group 0 to 9.8969e-04.
# Epoch 0.65: adjusting learning rate of group 0 to 9.8963e-04.
# Epoch 0.65: adjusting learning rate of group 0 to 9.8958e-04.
# Epoch 0.65: adjusting learning rate of group 0 to 9.8953e-04.
# Epoch 0.65: adjusting learning rate of group 0 to 9.8948e-04.
# Epoch 0.66: adjusting learning rate of group 0 to 9.8943e-04.
# Epoch 0.66: adjusting learning rate of group 0 to 9.8937e-04.
# Epoch 0.66: adjusting learning rate of group 0 to 9.8932e-04.
# Epoch 0.66: adjusting learning rate of group 0 to 9.8927e-04.
# Epoch 0.66: adjusting learning rate of group 0 to 9.8922e-04.
# Epoch 0.66: adjusting learning rate of group 0 to 9.8916e-04.
# Epoch 0.67: adjusting learning rate of group 0 to 9.8911e-04.
# Epoch 0.67: adjusting learning rate of group 0 to 9.8906e-04.
# Epoch 0.67: adjusting learning rate of group 0 to 9.8900e-04.
# Epoch 0.67: adjusting learning rate of group 0 to 9.8895e-04.
# Epoch 0.67: adjusting learning rate of group 0 to 9.8890e-04.
# Epoch 0.67: adjusting learning rate of group 0 to 9.8884e-04.
# Epoch 0.68: adjusting learning rate of group 0 to 9.8879e-04.
# Epoch 0.68: adjusting learning rate of group 0 to 9.8873e-04.
# Epoch 0.68: adjusting learning rate of group 0 to 9.8868e-04.
# Epoch 0.68: adjusting learning rate of group 0 to 9.8863e-04.
# Epoch 0.68: adjusting learning rate of group 0 to 9.8857e-04.
# Epoch 0.68: adjusting learning rate of group 0 to 9.8852e-04.
# Epoch 0.69: adjusting learning rate of group 0 to 9.8846e-04.
# Epoch 0.69: adjusting learning rate of group 0 to 9.8841e-04.
# Epoch 0.69: adjusting learning rate of group 0 to 9.8835e-04.
# Epoch 0.69: adjusting learning rate of group 0 to 9.8830e-04.
# Epoch 0.69: adjusting learning rate of group 0 to 9.8824e-04.
# Epoch 0.69: adjusting learning rate of group 0 to 9.8819e-04.
# Epoch 0.69: adjusting learning rate of group 0 to 9.8813e-04.
# Epoch 0.70: adjusting learning rate of group 0 to 9.8808e-04.
# Epoch 0.70: adjusting learning rate of group 0 to 9.8802e-04.
# Epoch 0.70: adjusting learning rate of group 0 to 9.8796e-04.
# Epoch 0.70: adjusting learning rate of group 0 to 9.8791e-04.
# Epoch 0.70: adjusting learning rate of group 0 to 9.8785e-04.
# Epoch 0.70: adjusting learning rate of group 0 to 9.8780e-04.
# Epoch 0.71: adjusting learning rate of group 0 to 9.8774e-04.
# Epoch 0.71: adjusting learning rate of group 0 to 9.8768e-04.
# Epoch 0.71: adjusting learning rate of group 0 to 9.8763e-04.
# Epoch 0.71: adjusting learning rate of group 0 to 9.8757e-04.
# Epoch 0.71: adjusting learning rate of group 0 to 9.8751e-04.
# Epoch 0.71: adjusting learning rate of group 0 to 9.8746e-04.
# Epoch 0.72: adjusting learning rate of group 0 to 9.8740e-04.
# Epoch 0.72: adjusting learning rate of group 0 to 9.8734e-04.
# Epoch 0.72: adjusting learning rate of group 0 to 9.8728e-04.
# Epoch 0.72: adjusting learning rate of group 0 to 9.8723e-04.
# Epoch 0.72: adjusting learning rate of group 0 to 9.8717e-04.
# Epoch 0.72: adjusting learning rate of group 0 to 9.8711e-04.
# Epoch 0.73: adjusting learning rate of group 0 to 9.8705e-04.
# Epoch 0.73: adjusting learning rate of group 0 to 9.8700e-04.
# Epoch 0.73: adjusting learning rate of group 0 to 9.8694e-04.
# Epoch 0.73: adjusting learning rate of group 0 to 9.8688e-04.
# Epoch 0.73: adjusting learning rate of group 0 to 9.8682e-04.
# Epoch 0.73: adjusting learning rate of group 0 to 9.8676e-04.
# Epoch 0.74: adjusting learning rate of group 0 to 9.8670e-04.
# Epoch 0.74: adjusting learning rate of group 0 to 9.8664e-04.
# Epoch 0.74: adjusting learning rate of group 0 to 9.8659e-04.
# Epoch 0.74: adjusting learning rate of group 0 to 9.8653e-04.
# Epoch 0.74: adjusting learning rate of group 0 to 9.8647e-04.
# Epoch 0.74: adjusting learning rate of group 0 to 9.8641e-04.
# Epoch 0.75: adjusting learning rate of group 0 to 9.8635e-04.
# Epoch 0.75: adjusting learning rate of group 0 to 9.8629e-04.
# Epoch 0.75: adjusting learning rate of group 0 to 9.8623e-04.
# Epoch 0.75: adjusting learning rate of group 0 to 9.8617e-04.
# Epoch 0.75: adjusting learning rate of group 0 to 9.8611e-04.
# Epoch 0.75: adjusting learning rate of group 0 to 9.8605e-04.
# Epoch 0.76: adjusting learning rate of group 0 to 9.8599e-04.
# Epoch 0.76: adjusting learning rate of group 0 to 9.8593e-04.
# Epoch 0.76: adjusting learning rate of group 0 to 9.8587e-04.
# Epoch 0.76: adjusting learning rate of group 0 to 9.8581e-04.
# Epoch 0.76: adjusting learning rate of group 0 to 9.8575e-04.
# Epoch 0.76: adjusting learning rate of group 0 to 9.8569e-04.
# Epoch 0.77: adjusting learning rate of group 0 to 9.8563e-04.
# Epoch 0.77: adjusting learning rate of group 0 to 9.8557e-04.
# Epoch 0.77: adjusting learning rate of group 0 to 9.8550e-04.
# Epoch 0.77: adjusting learning rate of group 0 to 9.8544e-04.
# Epoch 0.77: adjusting learning rate of group 0 to 9.8538e-04.
# Epoch 0.77: adjusting learning rate of group 0 to 9.8532e-04.
# Epoch 0.77: adjusting learning rate of group 0 to 9.8526e-04.
# Epoch 0.78: adjusting learning rate of group 0 to 9.8520e-04.
# Epoch 0.78: adjusting learning rate of group 0 to 9.8513e-04.
# Epoch 0.78: adjusting learning rate of group 0 to 9.8507e-04.
# Epoch 0.78: adjusting learning rate of group 0 to 9.8501e-04.
# Epoch 0.78: adjusting learning rate of group 0 to 9.8495e-04.
# Epoch 0.78: adjusting learning rate of group 0 to 9.8488e-04.
# Epoch 0.79: adjusting learning rate of group 0 to 9.8482e-04.
# Epoch 0.79: adjusting learning rate of group 0 to 9.8476e-04.
# Epoch 0.79: adjusting learning rate of group 0 to 9.8470e-04.
# Epoch 0.79: adjusting learning rate of group 0 to 9.8463e-04.
# Epoch 0.79: adjusting learning rate of group 0 to 9.8457e-04.
# Epoch 0.79: adjusting learning rate of group 0 to 9.8451e-04.
# Epoch 0.80: adjusting learning rate of group 0 to 9.8444e-04.
# Epoch 0.80: adjusting learning rate of group 0 to 9.8438e-04.
# Epoch 0.80: adjusting learning rate of group 0 to 9.8432e-04.
# Epoch 0.80: adjusting learning rate of group 0 to 9.8425e-04.
# Epoch 0.80: adjusting learning rate of group 0 to 9.8419e-04.
# Epoch 0.80: adjusting learning rate of group 0 to 9.8413e-04.
# Epoch 0.81: adjusting learning rate of group 0 to 9.8406e-04.
# Epoch 0.81: adjusting learning rate of group 0 to 9.8400e-04.
# Epoch 0.81: adjusting learning rate of group 0 to 9.8393e-04.
# Epoch 0.81: adjusting learning rate of group 0 to 9.8387e-04.
# Epoch 0.81: adjusting learning rate of group 0 to 9.8380e-04.
# Epoch 0.81: adjusting learning rate of group 0 to 9.8374e-04.
# Epoch 0.82: adjusting learning rate of group 0 to 9.8367e-04.
# Epoch 0.82: adjusting learning rate of group 0 to 9.8361e-04.
# Epoch 0.82: adjusting learning rate of group 0 to 9.8354e-04.
# Epoch 0.82: adjusting learning rate of group 0 to 9.8348e-04.
# Epoch 0.82: adjusting learning rate of group 0 to 9.8341e-04.
# Epoch 0.82: adjusting learning rate of group 0 to 9.8335e-04.
# Epoch 0.83: adjusting learning rate of group 0 to 9.8328e-04.
# Epoch 0.83: adjusting learning rate of group 0 to 9.8322e-04.
# Epoch 0.83: adjusting learning rate of group 0 to 9.8315e-04.
# Epoch 0.83: adjusting learning rate of group 0 to 9.8308e-04.
# Epoch 0.83: adjusting learning rate of group 0 to 9.8302e-04.
# Epoch 0.83: adjusting learning rate of group 0 to 9.8295e-04.
# Epoch 0.84: adjusting learning rate of group 0 to 9.8289e-04.
# Epoch 0.84: adjusting learning rate of group 0 to 9.8282e-04.
# Epoch 0.84: adjusting learning rate of group 0 to 9.8275e-04.
# Epoch 0.84: adjusting learning rate of group 0 to 9.8269e-04.
# Epoch 0.84: adjusting learning rate of group 0 to 9.8262e-04.
# Epoch 0.84: adjusting learning rate of group 0 to 9.8255e-04.
# Epoch 0.85: adjusting learning rate of group 0 to 9.8248e-04.
# Epoch 0.85: adjusting learning rate of group 0 to 9.8242e-04.
# Epoch 0.85: adjusting learning rate of group 0 to 9.8235e-04.
# Epoch 0.85: adjusting learning rate of group 0 to 9.8228e-04.
# Epoch 0.85: adjusting learning rate of group 0 to 9.8221e-04.
# Epoch 0.85: adjusting learning rate of group 0 to 9.8215e-04.
# Epoch 0.85: adjusting learning rate of group 0 to 9.8208e-04.
# Epoch 0.86: adjusting learning rate of group 0 to 9.8201e-04.
# Epoch 0.86: adjusting learning rate of group 0 to 9.8194e-04.
# Epoch 0.86: adjusting learning rate of group 0 to 9.8187e-04.
# Epoch 0.86: adjusting learning rate of group 0 to 9.8181e-04.
# Epoch 0.86: adjusting learning rate of group 0 to 9.8174e-04.
# Epoch 0.86: adjusting learning rate of group 0 to 9.8167e-04.
# Epoch 0.87: adjusting learning rate of group 0 to 9.8160e-04.
# Epoch 0.87: adjusting learning rate of group 0 to 9.8153e-04.
# Epoch 0.87: adjusting learning rate of group 0 to 9.8146e-04.
# Epoch 0.87: adjusting learning rate of group 0 to 9.8139e-04.
# Epoch 0.87: adjusting learning rate of group 0 to 9.8132e-04.
# Epoch 0.87: adjusting learning rate of group 0 to 9.8125e-04.
# Epoch 0.88: adjusting learning rate of group 0 to 9.8118e-04.
# Epoch 0.88: adjusting learning rate of group 0 to 9.8111e-04.
# Epoch 0.88: adjusting learning rate of group 0 to 9.8104e-04.
# Epoch 0.88: adjusting learning rate of group 0 to 9.8097e-04.
# Epoch 0.88: adjusting learning rate of group 0 to 9.8090e-04.
# Epoch 0.88: adjusting learning rate of group 0 to 9.8083e-04.
# Epoch 0.89: adjusting learning rate of group 0 to 9.8076e-04.
# Epoch 0.89: adjusting learning rate of group 0 to 9.8069e-04.
# Epoch 0.89: adjusting learning rate of group 0 to 9.8062e-04.
# Epoch 0.89: adjusting learning rate of group 0 to 9.8055e-04.
# Epoch 0.89: adjusting learning rate of group 0 to 9.8048e-04.
# Epoch 0.89: adjusting learning rate of group 0 to 9.8041e-04.
# Epoch 0.90: adjusting learning rate of group 0 to 9.8034e-04.
# Epoch 0.90: adjusting learning rate of group 0 to 9.8027e-04.
# Epoch 0.90: adjusting learning rate of group 0 to 9.8020e-04.
# Epoch 0.90: adjusting learning rate of group 0 to 9.8013e-04.
# Epoch 0.90: adjusting learning rate of group 0 to 9.8005e-04.
# Epoch 0.90: adjusting learning rate of group 0 to 9.7998e-04.
# Epoch 0.91: adjusting learning rate of group 0 to 9.7991e-04.
# Epoch 0.91: adjusting learning rate of group 0 to 9.7984e-04.
# Epoch 0.91: adjusting learning rate of group 0 to 9.7977e-04.
# Epoch 0.91: adjusting learning rate of group 0 to 9.7969e-04.
# Epoch 0.91: adjusting learning rate of group 0 to 9.7962e-04.
# Epoch 0.91: adjusting learning rate of group 0 to 9.7955e-04.
# Epoch 0.92: adjusting learning rate of group 0 to 9.7948e-04.
# Epoch 0.92: adjusting learning rate of group 0 to 9.7940e-04.
# Epoch 0.92: adjusting learning rate of group 0 to 9.7933e-04.
# Epoch 0.92: adjusting learning rate of group 0 to 9.7926e-04.
# Epoch 0.92: adjusting learning rate of group 0 to 9.7918e-04.
# Epoch 0.92: adjusting learning rate of group 0 to 9.7911e-04.
# Epoch 0.92: adjusting learning rate of group 0 to 9.7904e-04.
# Epoch 0.93: adjusting learning rate of group 0 to 9.7896e-04.
# Epoch 0.93: adjusting learning rate of group 0 to 9.7889e-04.
# Epoch 0.93: adjusting learning rate of group 0 to 9.7882e-04.
# Epoch 0.93: adjusting learning rate of group 0 to 9.7874e-04.
# Epoch 0.93: adjusting learning rate of group 0 to 9.7867e-04.
# Epoch 0.93: adjusting learning rate of group 0 to 9.7860e-04.
# Epoch 0.94: adjusting learning rate of group 0 to 9.7852e-04.
# Epoch 0.94: adjusting learning rate of group 0 to 9.7845e-04.
# Epoch 0.94: adjusting learning rate of group 0 to 9.7837e-04.
# Epoch 0.94: adjusting learning rate of group 0 to 9.7830e-04.
# Epoch 0.94: adjusting learning rate of group 0 to 9.7822e-04.
# Epoch 0.94: adjusting learning rate of group 0 to 9.7815e-04.
# Epoch 0.95: adjusting learning rate of group 0 to 9.7807e-04.
# Epoch 0.95: adjusting learning rate of group 0 to 9.7800e-04.
# Epoch 0.95: adjusting learning rate of group 0 to 9.7792e-04.
# Epoch 0.95: adjusting learning rate of group 0 to 9.7785e-04.
# Epoch 0.95: adjusting learning rate of group 0 to 9.7777e-04.
# Epoch 0.95: adjusting learning rate of group 0 to 9.7770e-04.
# Epoch 0.96: adjusting learning rate of group 0 to 9.7762e-04.
# Epoch 0.96: adjusting learning rate of group 0 to 9.7754e-04.
# Epoch 0.96: adjusting learning rate of group 0 to 9.7747e-04.
# Epoch 0.96: adjusting learning rate of group 0 to 9.7739e-04.
# Epoch 0.96: adjusting learning rate of group 0 to 9.7732e-04.
# Epoch 0.96: adjusting learning rate of group 0 to 9.7724e-04.
# Epoch 0.97: adjusting learning rate of group 0 to 9.7716e-04.
# Epoch 0.97: adjusting learning rate of group 0 to 9.7709e-04.
# Epoch 0.97: adjusting learning rate of group 0 to 9.7701e-04.
# Epoch 0.97: adjusting learning rate of group 0 to 9.7693e-04.
# Epoch 0.97: adjusting learning rate of group 0 to 9.7686e-04.
# Epoch 0.97: adjusting learning rate of group 0 to 9.7678e-04.
# Epoch 0.98: adjusting learning rate of group 0 to 9.7670e-04.
# Epoch 0.98: adjusting learning rate of group 0 to 9.7662e-04.
# Epoch 0.98: adjusting learning rate of group 0 to 9.7655e-04.
# Epoch 0.98: adjusting learning rate of group 0 to 9.7647e-04.
# Epoch 0.98: adjusting learning rate of group 0 to 9.7639e-04.
# Epoch 0.98: adjusting learning rate of group 0 to 9.7631e-04.
# Epoch 0.99: adjusting learning rate of group 0 to 9.7624e-04.
# Epoch 0.99: adjusting learning rate of group 0 to 9.7616e-04.
# Epoch 0.99: adjusting learning rate of group 0 to 9.7608e-04.
# Epoch 0.99: adjusting learning rate of group 0 to 9.7600e-04.
# Epoch 0.99: adjusting learning rate of group 0 to 9.7592e-04.
# Epoch 0.99: adjusting learning rate of group 0 to 9.7584e-04.
# Epoch 1.00: adjusting learning rate of group 0 to 9.7577e-04.
# Epoch 1.00: adjusting learning rate of group 0 to 9.7569e-04.
# Epoch 1.00: adjusting learning rate of group 0 to 9.7561e-04.
# Validation
#
#
# Accuracy of class 0: 0.0
# Accuracy of class 1: 0.0
# Accuracy of class 2: 0.0
# Accuracy of class 3: 0.0
# Accuracy of class 4: 0.0
# Accuracy of class 5: 0.0
# Accuracy of class 6: 0.0
# Accuracy of class 7: 0.0
# Accuracy of class 8: 0.0
# Accuracy of class 9: 0.0
# Accuracy of class 10: 0.0
# Accuracy of class 11: 0.0
# Accuracy of class 12: 0.0
# Accuracy of class 13: 0.0
# Accuracy of class 14: 0.0
# Accuracy of class 15: 0.0
# Accuracy of class 16: 0.0
# Accuracy of class 17: 0.0
# Accuracy of class 18: 0.0
# Accuracy of class 19: 0.0
# Accuracy of class 20: 0.0
# Accuracy of class 21: 0.0
# Accuracy of class 22: 0.0
# Accuracy of class 23: 0.0
# Accuracy of class 24: 0.0
# Accuracy of class 25: 0.0
# Accuracy of class 26: 0.0
# Accuracy of class 27: 0.0
# Accuracy of class 28: 0.0
# Accuracy of class 29: 0.0
# Accuracy of class 30: 0.0
# Accuracy of class 31: 0.0
# Accuracy of class 32: 0.0
# Accuracy of class 33: 0.0
# Accuracy of class 34: 0.0
# Accuracy of class 35: 0.0
# Accuracy of class 36: 0.0
# Accuracy of class 37: 0.0
# Accuracy of class 38: 0.0
# Accuracy of class 39: 0.0
# Accuracy of class 40: 0.0
# Accuracy of class 41: 0.07092198581560284
# Accuracy of class 42: 100.0
#
#
# Training loss: 3.108, training acc: 60.047
# Validation loss: 20.419, validation acc: 3.752
# --------------------------------------------------
# [INFO]: Epoch 2 of 4
# Training
# Epoch 1.00: adjusting learning rate of group 0 to 9.7553e-04.
# Epoch 1.00: adjusting learning rate of group 0 to 9.7545e-04.
# Epoch 1.00: adjusting learning rate of group 0 to 9.7537e-04.
# Epoch 1.00: adjusting learning rate of group 0 to 9.7529e-04.
# Epoch 1.01: adjusting learning rate of group 0 to 9.7521e-04.
# Epoch 1.01: adjusting learning rate of group 0 to 9.7513e-04.
# Epoch 1.01: adjusting learning rate of group 0 to 9.7505e-04.
# Epoch 1.01: adjusting learning rate of group 0 to 9.7497e-04.
# Epoch 1.01: adjusting learning rate of group 0 to 9.7489e-04.
# Epoch 1.01: adjusting learning rate of group 0 to 9.7481e-04.
# Epoch 1.02: adjusting learning rate of group 0 to 9.7473e-04.
# Epoch 1.02: adjusting learning rate of group 0 to 9.7465e-04.
# Epoch 1.02: adjusting learning rate of group 0 to 9.7457e-04.
# Epoch 1.02: adjusting learning rate of group 0 to 9.7449e-04.
# Epoch 1.02: adjusting learning rate of group 0 to 9.7441e-04.
# Epoch 1.02: adjusting learning rate of group 0 to 9.7433e-04.
# Epoch 1.03: adjusting learning rate of group 0 to 9.7425e-04.
# Epoch 1.03: adjusting learning rate of group 0 to 9.7416e-04.
# Epoch 1.03: adjusting learning rate of group 0 to 9.7408e-04.
# Epoch 1.03: adjusting learning rate of group 0 to 9.7400e-04.
# Epoch 1.03: adjusting learning rate of group 0 to 9.7392e-04.
# Epoch 1.03: adjusting learning rate of group 0 to 9.7384e-04.
# Epoch 1.04: adjusting learning rate of group 0 to 9.7376e-04.
# Epoch 1.04: adjusting learning rate of group 0 to 9.7367e-04.
# Epoch 1.04: adjusting learning rate of group 0 to 9.7359e-04.
# Epoch 1.04: adjusting learning rate of group 0 to 9.7351e-04.
# Epoch 1.04: adjusting learning rate of group 0 to 9.7343e-04.
# Epoch 1.04: adjusting learning rate of group 0 to 9.7334e-04.
# Epoch 1.05: adjusting learning rate of group 0 to 9.7326e-04.
# Epoch 1.05: adjusting learning rate of group 0 to 9.7318e-04.
# Epoch 1.05: adjusting learning rate of group 0 to 9.7310e-04.
# Epoch 1.05: adjusting learning rate of group 0 to 9.7301e-04.
# Epoch 1.05: adjusting learning rate of group 0 to 9.7293e-04.
# Epoch 1.05: adjusting learning rate of group 0 to 9.7285e-04.
# Epoch 1.06: adjusting learning rate of group 0 to 9.7276e-04.
# Epoch 1.06: adjusting learning rate of group 0 to 9.7268e-04.
# Epoch 1.06: adjusting learning rate of group 0 to 9.7260e-04.
# Epoch 1.06: adjusting learning rate of group 0 to 9.7251e-04.
# Epoch 1.06: adjusting learning rate of group 0 to 9.7243e-04.
# Epoch 1.06: adjusting learning rate of group 0 to 9.7235e-04.
# Epoch 1.07: adjusting learning rate of group 0 to 9.7226e-04.
# Epoch 1.07: adjusting learning rate of group 0 to 9.7218e-04.
# Epoch 1.07: adjusting learning rate of group 0 to 9.7209e-04.
# Epoch 1.07: adjusting learning rate of group 0 to 9.7201e-04.
# Epoch 1.07: adjusting learning rate of group 0 to 9.7192e-04.
# Epoch 1.07: adjusting learning rate of group 0 to 9.7184e-04.
# Epoch 1.08: adjusting learning rate of group 0 to 9.7175e-04.
# Epoch 1.08: adjusting learning rate of group 0 to 9.7167e-04.
# Epoch 1.08: adjusting learning rate of group 0 to 9.7158e-04.
# Epoch 1.08: adjusting learning rate of group 0 to 9.7150e-04.
# Epoch 1.08: adjusting learning rate of group 0 to 9.7141e-04.
# Epoch 1.08: adjusting learning rate of group 0 to 9.7133e-04.
# Epoch 1.08: adjusting learning rate of group 0 to 9.7124e-04.
# Epoch 1.09: adjusting learning rate of group 0 to 9.7116e-04.
# Epoch 1.09: adjusting learning rate of group 0 to 9.7107e-04.
# Epoch 1.09: adjusting learning rate of group 0 to 9.7098e-04.
# Epoch 1.09: adjusting learning rate of group 0 to 9.7090e-04.
# Epoch 1.09: adjusting learning rate of group 0 to 9.7081e-04.
# Epoch 1.09: adjusting learning rate of group 0 to 9.7073e-04.
# Epoch 1.10: adjusting learning rate of group 0 to 9.7064e-04.
# Epoch 1.10: adjusting learning rate of group 0 to 9.7055e-04.
# Epoch 1.10: adjusting learning rate of group 0 to 9.7047e-04.
# Epoch 1.10: adjusting learning rate of group 0 to 9.7038e-04.
# Epoch 1.10: adjusting learning rate of group 0 to 9.7029e-04.
# Epoch 1.10: adjusting learning rate of group 0 to 9.7021e-04.
# Epoch 1.11: adjusting learning rate of group 0 to 9.7012e-04.
# Epoch 1.11: adjusting learning rate of group 0 to 9.7003e-04.
# Epoch 1.11: adjusting learning rate of group 0 to 9.6994e-04.
# Epoch 1.11: adjusting learning rate of group 0 to 9.6986e-04.
# Epoch 1.11: adjusting learning rate of group 0 to 9.6977e-04.
# Epoch 1.11: adjusting learning rate of group 0 to 9.6968e-04.
# Epoch 1.12: adjusting learning rate of group 0 to 9.6959e-04.
# Epoch 1.12: adjusting learning rate of group 0 to 9.6950e-04.
# Epoch 1.12: adjusting learning rate of group 0 to 9.6942e-04.
# Epoch 1.12: adjusting learning rate of group 0 to 9.6933e-04.
# Epoch 1.12: adjusting learning rate of group 0 to 9.6924e-04.
# Epoch 1.12: adjusting learning rate of group 0 to 9.6915e-04.
# Epoch 1.13: adjusting learning rate of group 0 to 9.6906e-04.
# Epoch 1.13: adjusting learning rate of group 0 to 9.6897e-04.
# Epoch 1.13: adjusting learning rate of group 0 to 9.6888e-04.
# Epoch 1.13: adjusting learning rate of group 0 to 9.6880e-04.
# Epoch 1.13: adjusting learning rate of group 0 to 9.6871e-04.
# Epoch 1.13: adjusting learning rate of group 0 to 9.6862e-04.
# Epoch 1.14: adjusting learning rate of group 0 to 9.6853e-04.
# Epoch 1.14: adjusting learning rate of group 0 to 9.6844e-04.
# Epoch 1.14: adjusting learning rate of group 0 to 9.6835e-04.
# Epoch 1.14: adjusting learning rate of group 0 to 9.6826e-04.
# Epoch 1.14: adjusting learning rate of group 0 to 9.6817e-04.
# Epoch 1.14: adjusting learning rate of group 0 to 9.6808e-04.
# Epoch 1.15: adjusting learning rate of group 0 to 9.6799e-04.
# Epoch 1.15: adjusting learning rate of group 0 to 9.6790e-04.
# Epoch 1.15: adjusting learning rate of group 0 to 9.6781e-04.
# Epoch 1.15: adjusting learning rate of group 0 to 9.6772e-04.
# Epoch 1.15: adjusting learning rate of group 0 to 9.6763e-04.
# Epoch 1.15: adjusting learning rate of group 0 to 9.6754e-04.
# Epoch 1.15: adjusting learning rate of group 0 to 9.6745e-04.
# Epoch 1.16: adjusting learning rate of group 0 to 9.6735e-04.
# Epoch 1.16: adjusting learning rate of group 0 to 9.6726e-04.
# Epoch 1.16: adjusting learning rate of group 0 to 9.6717e-04.
# Epoch 1.16: adjusting learning rate of group 0 to 9.6708e-04.
# Epoch 1.16: adjusting learning rate of group 0 to 9.6699e-04.
# Epoch 1.16: adjusting learning rate of group 0 to 9.6690e-04.
# Epoch 1.17: adjusting learning rate of group 0 to 9.6681e-04.
# Epoch 1.17: adjusting learning rate of group 0 to 9.6671e-04.
# Epoch 1.17: adjusting learning rate of group 0 to 9.6662e-04.
# Epoch 1.17: adjusting learning rate of group 0 to 9.6653e-04.
# Epoch 1.17: adjusting learning rate of group 0 to 9.6644e-04.
# Epoch 1.17: adjusting learning rate of group 0 to 9.6634e-04.
# Epoch 1.18: adjusting learning rate of group 0 to 9.6625e-04.
# Epoch 1.18: adjusting learning rate of group 0 to 9.6616e-04.
# Epoch 1.18: adjusting learning rate of group 0 to 9.6607e-04.
# Epoch 1.18: adjusting learning rate of group 0 to 9.6597e-04.
# Epoch 1.18: adjusting learning rate of group 0 to 9.6588e-04.
# Epoch 1.18: adjusting learning rate of group 0 to 9.6579e-04.
# Epoch 1.19: adjusting learning rate of group 0 to 9.6569e-04.
# Epoch 1.19: adjusting learning rate of group 0 to 9.6560e-04.
# Epoch 1.19: adjusting learning rate of group 0 to 9.6551e-04.
# Epoch 1.19: adjusting learning rate of group 0 to 9.6541e-04.
# Epoch 1.19: adjusting learning rate of group 0 to 9.6532e-04.
# Epoch 1.19: adjusting learning rate of group 0 to 9.6523e-04.
# Epoch 1.20: adjusting learning rate of group 0 to 9.6513e-04.
# Epoch 1.20: adjusting learning rate of group 0 to 9.6504e-04.
# Epoch 1.20: adjusting learning rate of group 0 to 9.6494e-04.
# Epoch 1.20: adjusting learning rate of group 0 to 9.6485e-04.
# Epoch 1.20: adjusting learning rate of group 0 to 9.6476e-04.
# ...
# Epoch 3.62: adjusting learning rate of group 0 to 7.1075e-04.
# Epoch 3.62: adjusting learning rate of group 0 to 7.1052e-04.
# Epoch 3.62: adjusting learning rate of group 0 to 7.1029e-04.
# Epoch 3.62: adjusting learning rate of group 0 to 7.1006e-04.
# Epoch 3.62: adjusting learning rate of group 0 to 7.0982e-04.
# Epoch 3.62: adjusting learning rate of group 0 to 7.0959e-04.
# Epoch 3.62: adjusting learning rate of group 0 to 7.0936e-04.
# Epoch 3.63: adjusting learning rate of group 0 to 7.0913e-04.
# Epoch 3.63: adjusting learning rate of group 0 to 7.0889e-04.
# Epoch 3.63: adjusting learning rate of group 0 to 7.0866e-04.
# Epoch 3.63: adjusting learning rate of group 0 to 7.0843e-04.
# Epoch 3.63: adjusting learning rate of group 0 to 7.0819e-04.
# Epoch 3.63: adjusting learning rate of group 0 to 7.0796e-04.
# Epoch 3.64: adjusting learning rate of group 0 to 7.0773e-04.
# Epoch 3.64: adjusting learning rate of group 0 to 7.0750e-04.
# Epoch 3.64: adjusting learning rate of group 0 to 7.0726e-04.
# Epoch 3.64: adjusting learning rate of group 0 to 7.0703e-04.
# Epoch 3.64: adjusting learning rate of group 0 to 7.0680e-04.
# Epoch 3.64: adjusting learning rate of group 0 to 7.0656e-04.
# Epoch 3.65: adjusting learning rate of group 0 to 7.0633e-04.
# Epoch 3.65: adjusting learning rate of group 0 to 7.0610e-04.
# Epoch 3.65: adjusting learning rate of group 0 to 7.0586e-04.
# Epoch 3.65: adjusting learning rate of group 0 to 7.0563e-04.
# Epoch 3.65: adjusting learning rate of group 0 to 7.0540e-04.
# Epoch 3.65: adjusting learning rate of group 0 to 7.0516e-04.
# Epoch 3.66: adjusting learning rate of group 0 to 7.0493e-04.
# Epoch 3.66: adjusting learning rate of group 0 to 7.0469e-04.
# Epoch 3.66: adjusting learning rate of group 0 to 7.0446e-04.
# Epoch 3.66: adjusting learning rate of group 0 to 7.0423e-04.
# Epoch 3.66: adjusting learning rate of group 0 to 7.0399e-04.
# Epoch 3.66: adjusting learning rate of group 0 to 7.0376e-04.
# Epoch 3.67: adjusting learning rate of group 0 to 7.0352e-04.
# Epoch 3.67: adjusting learning rate of group 0 to 7.0329e-04.
# Epoch 3.67: adjusting learning rate of group 0 to 7.0306e-04.
# Epoch 3.67: adjusting learning rate of group 0 to 7.0282e-04.
# Epoch 3.67: adjusting learning rate of group 0 to 7.0259e-04.
# Epoch 3.67: adjusting learning rate of group 0 to 7.0235e-04.
# Epoch 3.68: adjusting learning rate of group 0 to 7.0212e-04.
# Epoch 3.68: adjusting learning rate of group 0 to 7.0188e-04.
# Epoch 3.68: adjusting learning rate of group 0 to 7.0165e-04.
# Epoch 3.68: adjusting learning rate of group 0 to 7.0142e-04.
# Epoch 3.68: adjusting learning rate of group 0 to 7.0118e-04.
# Epoch 3.68: adjusting learning rate of group 0 to 7.0095e-04.
# Epoch 3.69: adjusting learning rate of group 0 to 7.0071e-04.
# Epoch 3.69: adjusting learning rate of group 0 to 7.0048e-04.
# Epoch 3.69: adjusting learning rate of group 0 to 7.0024e-04.
# Epoch 3.69: adjusting learning rate of group 0 to 7.0001e-04.
# Epoch 3.69: adjusting learning rate of group 0 to 6.9977e-04.
# Epoch 3.69: adjusting learning rate of group 0 to 6.9954e-04.
# Epoch 3.69: adjusting learning rate of group 0 to 6.9930e-04.
# Epoch 3.70: adjusting learning rate of group 0 to 6.9907e-04.
# Epoch 3.70: adjusting learning rate of group 0 to 6.9883e-04.
# Epoch 3.70: adjusting learning rate of group 0 to 6.9860e-04.
# Epoch 3.70: adjusting learning rate of group 0 to 6.9836e-04.
# Epoch 3.70: adjusting learning rate of group 0 to 6.9813e-04.
# Epoch 3.70: adjusting learning rate of group 0 to 6.9789e-04.
# Epoch 3.71: adjusting learning rate of group 0 to 6.9766e-04.
# Epoch 3.71: adjusting learning rate of group 0 to 6.9742e-04.
# Epoch 3.71: adjusting learning rate of group 0 to 6.9719e-04.
# Epoch 3.71: adjusting learning rate of group 0 to 6.9695e-04.
# Epoch 3.71: adjusting learning rate of group 0 to 6.9671e-04.
# Epoch 3.71: adjusting learning rate of group 0 to 6.9648e-04.
# Epoch 3.72: adjusting learning rate of group 0 to 6.9624e-04.
# Epoch 3.72: adjusting learning rate of group 0 to 6.9601e-04.
# Epoch 3.72: adjusting learning rate of group 0 to 6.9577e-04.
# Epoch 3.72: adjusting learning rate of group 0 to 6.9554e-04.
# Epoch 3.72: adjusting learning rate of group 0 to 6.9530e-04.
# Epoch 3.72: adjusting learning rate of group 0 to 6.9506e-04.
# Epoch 3.73: adjusting learning rate of group 0 to 6.9483e-04.
# Epoch 3.73: adjusting learning rate of group 0 to 6.9459e-04.
# Epoch 3.73: adjusting learning rate of group 0 to 6.9436e-04.
# Epoch 3.73: adjusting learning rate of group 0 to 6.9412e-04.
# Epoch 3.73: adjusting learning rate of group 0 to 6.9388e-04.
# Epoch 3.73: adjusting learning rate of group 0 to 6.9365e-04.
# Epoch 3.74: adjusting learning rate of group 0 to 6.9341e-04.
# Epoch 3.74: adjusting learning rate of group 0 to 6.9317e-04.
# Epoch 3.74: adjusting learning rate of group 0 to 6.9294e-04.
# Epoch 3.74: adjusting learning rate of group 0 to 6.9270e-04.
# Epoch 3.74: adjusting learning rate of group 0 to 6.9247e-04.
# Epoch 3.74: adjusting learning rate of group 0 to 6.9223e-04.
# Epoch 3.75: adjusting learning rate of group 0 to 6.9199e-04.
# Epoch 3.75: adjusting learning rate of group 0 to 6.9176e-04.
# Epoch 3.75: adjusting learning rate of group 0 to 6.9152e-04.
# Epoch 3.75: adjusting learning rate of group 0 to 6.9128e-04.
# Epoch 3.75: adjusting learning rate of group 0 to 6.9105e-04.
# Epoch 3.75: adjusting learning rate of group 0 to 6.9081e-04.
# Epoch 3.76: adjusting learning rate of group 0 to 6.9057e-04.
# Epoch 3.76: adjusting learning rate of group 0 to 6.9034e-04.
# Epoch 3.76: adjusting learning rate of group 0 to 6.9010e-04.
# Epoch 3.76: adjusting learning rate of group 0 to 6.8986e-04.
# Epoch 3.76: adjusting learning rate of group 0 to 6.8962e-04.
# Epoch 3.76: adjusting learning rate of group 0 to 6.8939e-04.
# Epoch 3.77: adjusting learning rate of group 0 to 6.8915e-04.
# Epoch 3.77: adjusting learning rate of group 0 to 6.8891e-04.
# Epoch 3.77: adjusting learning rate of group 0 to 6.8868e-04.
# Epoch 3.77: adjusting learning rate of group 0 to 6.8844e-04.
# Epoch 3.77: adjusting learning rate of group 0 to 6.8820e-04.
# Epoch 3.77: adjusting learning rate of group 0 to 6.8796e-04.
# Epoch 3.77: adjusting learning rate of group 0 to 6.8773e-04.
# Epoch 3.78: adjusting learning rate of group 0 to 6.8749e-04.
# Epoch 3.78: adjusting learning rate of group 0 to 6.8725e-04.
# Epoch 3.78: adjusting learning rate of group 0 to 6.8701e-04.
# Epoch 3.78: adjusting learning rate of group 0 to 6.8678e-04.
# Epoch 3.78: adjusting learning rate of group 0 to 6.8654e-04.
# Epoch 3.78: adjusting learning rate of group 0 to 6.8630e-04.
# Epoch 3.79: adjusting learning rate of group 0 to 6.8606e-04.
# Epoch 3.79: adjusting learning rate of group 0 to 6.8582e-04.
# Epoch 3.79: adjusting learning rate of group 0 to 6.8559e-04.
# Epoch 3.79: adjusting learning rate of group 0 to 6.8535e-04.
# Epoch 3.79: adjusting learning rate of group 0 to 6.8511e-04.
# Epoch 3.79: adjusting learning rate of group 0 to 6.8487e-04.
# Epoch 3.80: adjusting learning rate of group 0 to 6.8463e-04.
# Epoch 3.80: adjusting learning rate of group 0 to 6.8440e-04.
# Epoch 3.80: adjusting learning rate of group 0 to 6.8416e-04.
# Epoch 3.80: adjusting learning rate of group 0 to 6.8392e-04.
# Epoch 3.80: adjusting learning rate of group 0 to 6.8368e-04.
# Epoch 3.80: adjusting learning rate of group 0 to 6.8344e-04.
# Epoch 3.81: adjusting learning rate of group 0 to 6.8320e-04.
# Epoch 3.81: adjusting learning rate of group 0 to 6.8297e-04.
# Epoch 3.81: adjusting learning rate of group 0 to 6.8273e-04.
# Epoch 3.81: adjusting learning rate of group 0 to 6.8249e-04.
# Epoch 3.81: adjusting learning rate of group 0 to 6.8225e-04.
# Epoch 3.81: adjusting learning rate of group 0 to 6.8201e-04.
# Epoch 3.82: adjusting learning rate of group 0 to 6.8177e-04.
# Epoch 3.82: adjusting learning rate of group 0 to 6.8153e-04.
# Epoch 3.82: adjusting learning rate of group 0 to 6.8130e-04.
# Epoch 3.82: adjusting learning rate of group 0 to 6.8106e-04.
# Epoch 3.82: adjusting learning rate of group 0 to 6.8082e-04.
# Epoch 3.82: adjusting learning rate of group 0 to 6.8058e-04.
# Epoch 3.83: adjusting learning rate of group 0 to 6.8034e-04.
# Epoch 3.83: adjusting learning rate of group 0 to 6.8010e-04.
# Epoch 3.83: adjusting learning rate of group 0 to 6.7986e-04.
# Epoch 3.83: adjusting learning rate of group 0 to 6.7962e-04.
# Epoch 3.83: adjusting learning rate of group 0 to 6.7938e-04.
# Epoch 3.83: adjusting learning rate of group 0 to 6.7914e-04.
# Epoch 3.84: adjusting learning rate of group 0 to 6.7890e-04.
# Epoch 3.84: adjusting learning rate of group 0 to 6.7867e-04.
# Epoch 3.84: adjusting learning rate of group 0 to 6.7843e-04.
# Epoch 3.84: adjusting learning rate of group 0 to 6.7819e-04.
# Epoch 3.84: adjusting learning rate of group 0 to 6.7795e-04.
# Epoch 3.84: adjusting learning rate of group 0 to 6.7771e-04.
# Epoch 3.85: adjusting learning rate of group 0 to 6.7747e-04.
# Epoch 3.85: adjusting learning rate of group 0 to 6.7723e-04.
# Epoch 3.85: adjusting learning rate of group 0 to 6.7699e-04.
# Epoch 3.85: adjusting learning rate of group 0 to 6.7675e-04.
# Epoch 3.85: adjusting learning rate of group 0 to 6.7651e-04.
# Epoch 3.85: adjusting learning rate of group 0 to 6.7627e-04.
# Epoch 3.85: adjusting learning rate of group 0 to 6.7603e-04.
# Epoch 3.86: adjusting learning rate of group 0 to 6.7579e-04.
# Epoch 3.86: adjusting learning rate of group 0 to 6.7555e-04.
# Epoch 3.86: adjusting learning rate of group 0 to 6.7531e-04.
# Epoch 3.86: adjusting learning rate of group 0 to 6.7507e-04.
# Epoch 3.86: adjusting learning rate of group 0 to 6.7483e-04.
# Epoch 3.86: adjusting learning rate of group 0 to 6.7459e-04.
# Epoch 3.87: adjusting learning rate of group 0 to 6.7435e-04.
# Epoch 3.87: adjusting learning rate of group 0 to 6.7411e-04.
# Epoch 3.87: adjusting learning rate of group 0 to 6.7387e-04.
# Epoch 3.87: adjusting learning rate of group 0 to 6.7363e-04.
# Epoch 3.87: adjusting learning rate of group 0 to 6.7339e-04.
# Epoch 3.87: adjusting learning rate of group 0 to 6.7315e-04.
# Epoch 3.88: adjusting learning rate of group 0 to 6.7291e-04.
# Epoch 3.88: adjusting learning rate of group 0 to 6.7267e-04.
# Epoch 3.88: adjusting learning rate of group 0 to 6.7243e-04.
# Epoch 3.88: adjusting learning rate of group 0 to 6.7219e-04.
# Epoch 3.88: adjusting learning rate of group 0 to 6.7195e-04.
# Epoch 3.88: adjusting learning rate of group 0 to 6.7171e-04.
# Epoch 3.89: adjusting learning rate of group 0 to 6.7146e-04.
# Epoch 3.89: adjusting learning rate of group 0 to 6.7122e-04.
# Epoch 3.89: adjusting learning rate of group 0 to 6.7098e-04.
# Epoch 3.89: adjusting learning rate of group 0 to 6.7074e-04.
# Epoch 3.89: adjusting learning rate of group 0 to 6.7050e-04.
# Epoch 3.89: adjusting learning rate of group 0 to 6.7026e-04.
# Epoch 3.90: adjusting learning rate of group 0 to 6.7002e-04.
# Epoch 3.90: adjusting learning rate of group 0 to 6.6978e-04.
# Epoch 3.90: adjusting learning rate of group 0 to 6.6954e-04.
# Epoch 3.90: adjusting learning rate of group 0 to 6.6930e-04.
# Epoch 3.90: adjusting learning rate of group 0 to 6.6906e-04.
# Epoch 3.90: adjusting learning rate of group 0 to 6.6881e-04.
# Epoch 3.91: adjusting learning rate of group 0 to 6.6857e-04.
# Epoch 3.91: adjusting learning rate of group 0 to 6.6833e-04.
# Epoch 3.91: adjusting learning rate of group 0 to 6.6809e-04.
# Epoch 3.91: adjusting learning rate of group 0 to 6.6785e-04.
# Epoch 3.91: adjusting learning rate of group 0 to 6.6761e-04.
# Epoch 3.91: adjusting learning rate of group 0 to 6.6737e-04.
# Epoch 3.92: adjusting learning rate of group 0 to 6.6712e-04.
# Epoch 3.92: adjusting learning rate of group 0 to 6.6688e-04.
# Epoch 3.92: adjusting learning rate of group 0 to 6.6664e-04.
# Epoch 3.92: adjusting learning rate of group 0 to 6.6640e-04.
# Epoch 3.92: adjusting learning rate of group 0 to 6.6616e-04.
# Epoch 3.92: adjusting learning rate of group 0 to 6.6592e-04.
# Epoch 3.92: adjusting learning rate of group 0 to 6.6567e-04.
# Epoch 3.93: adjusting learning rate of group 0 to 6.6543e-04.
# Epoch 3.93: adjusting learning rate of group 0 to 6.6519e-04.
# Epoch 3.93: adjusting learning rate of group 0 to 6.6495e-04.
# Epoch 3.93: adjusting learning rate of group 0 to 6.6471e-04.
# Epoch 3.93: adjusting learning rate of group 0 to 6.6447e-04.
# Epoch 3.93: adjusting learning rate of group 0 to 6.6422e-04.
# Epoch 3.94: adjusting learning rate of group 0 to 6.6398e-04.
# Epoch 3.94: adjusting learning rate of group 0 to 6.6374e-04.
# Epoch 3.94: adjusting learning rate of group 0 to 6.6350e-04.
# Epoch 3.94: adjusting learning rate of group 0 to 6.6326e-04.
# Epoch 3.94: adjusting learning rate of group 0 to 6.6301e-04.
# Epoch 3.94: adjusting learning rate of group 0 to 6.6277e-04.
# Epoch 3.95: adjusting learning rate of group 0 to 6.6253e-04.
# Epoch 3.95: adjusting learning rate of group 0 to 6.6229e-04.
# Epoch 3.95: adjusting learning rate of group 0 to 6.6204e-04.
# Epoch 3.95: adjusting learning rate of group 0 to 6.6180e-04.
# Epoch 3.95: adjusting learning rate of group 0 to 6.6156e-04.
# Epoch 3.95: adjusting learning rate of group 0 to 6.6132e-04.
# Epoch 3.96: adjusting learning rate of group 0 to 6.6107e-04.
# Epoch 3.96: adjusting learning rate of group 0 to 6.6083e-04.
# Epoch 3.96: adjusting learning rate of group 0 to 6.6059e-04.
# Epoch 3.96: adjusting learning rate of group 0 to 6.6035e-04.
# Epoch 3.96: adjusting learning rate of group 0 to 6.6010e-04.
# Epoch 3.96: adjusting learning rate of group 0 to 6.5986e-04.
# Epoch 3.97: adjusting learning rate of group 0 to 6.5962e-04.
# Epoch 3.97: adjusting learning rate of group 0 to 6.5937e-04.
# Epoch 3.97: adjusting learning rate of group 0 to 6.5913e-04.
# Epoch 3.97: adjusting learning rate of group 0 to 6.5889e-04.
# Epoch 3.97: adjusting learning rate of group 0 to 6.5865e-04.
# Epoch 3.97: adjusting learning rate of group 0 to 6.5840e-04.
# Epoch 3.98: adjusting learning rate of group 0 to 6.5816e-04.
# Epoch 3.98: adjusting learning rate of group 0 to 6.5792e-04.
# Epoch 3.98: adjusting learning rate of group 0 to 6.5767e-04.
# Epoch 3.98: adjusting learning rate of group 0 to 6.5743e-04.
# Epoch 3.98: adjusting learning rate of group 0 to 6.5719e-04.
# Epoch 3.98: adjusting learning rate of group 0 to 6.5694e-04.
# Epoch 3.99: adjusting learning rate of group 0 to 6.5670e-04.
# Epoch 3.99: adjusting learning rate of group 0 to 6.5646e-04.
# Epoch 3.99: adjusting learning rate of group 0 to 6.5621e-04.
# Epoch 3.99: adjusting learning rate of group 0 to 6.5597e-04.
# Epoch 3.99: adjusting learning rate of group 0 to 6.5573e-04.
# Epoch 3.99: adjusting learning rate of group 0 to 6.5548e-04.
# Epoch 4.00: adjusting learning rate of group 0 to 6.5524e-04.
# Epoch 4.00: adjusting learning rate of group 0 to 6.5500e-04.
# Epoch 4.00: adjusting learning rate of group 0 to 6.5475e-04.
# Validation
#
#
# Accuracy of class 0: 0.0
# Accuracy of class 1: 0.0
# Accuracy of class 2: 0.0
# Accuracy of class 3: 0.0
# Accuracy of class 4: 0.0
# Accuracy of class 5: 0.0
# Accuracy of class 6: 0.1282051282051282
# Accuracy of class 7: 0.0
# Accuracy of class 8: 0.0
# Accuracy of class 9: 0.0
# Accuracy of class 10: 0.0
# Accuracy of class 11: 0.0
# Accuracy of class 12: 0.0
# Accuracy of class 13: 0.0
# Accuracy of class 14: 0.0
# Accuracy of class 15: 0.0
# Accuracy of class 16: 0.0
# Accuracy of class 17: 0.0
# Accuracy of class 18: 0.0
# Accuracy of class 19: 0.0
# Accuracy of class 20: 0.0
# Accuracy of class 21: 0.0
# Accuracy of class 22: 0.0
# Accuracy of class 23: 0.0
# Accuracy of class 24: 0.0
# Accuracy of class 25: 0.0
# Accuracy of class 26: 0.0
# Accuracy of class 27: 0.0
# Accuracy of class 28: 0.0
# Accuracy of class 29: 0.0
# Accuracy of class 30: 0.0
# Accuracy of class 31: 0.0
# Accuracy of class 32: 0.0
# Accuracy of class 33: 0.0
# Accuracy of class 34: 0.0
# Accuracy of class 35: 0.0
# Accuracy of class 36: 0.0
# Accuracy of class 37: 0.0
# Accuracy of class 38: 0.0
# Accuracy of class 39: 0.0
# Accuracy of class 40: 0.0
# Accuracy of class 41: 0.0
# Accuracy of class 42: 99.8639455782313
#
#
# Training loss: 2.618, training acc: 42.873
# Validation loss: 110.479, validation acc: 3.747
# --------------------------------------------------
# TRAINING COMPLETE
